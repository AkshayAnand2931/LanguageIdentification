# %%
pip install numpy pydub librosa soundfile
# Out:
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (1.26.4)
# Requirement already satisfied: pydub in /opt/conda/lib/python3.10/site-packages (0.25.1)
# Requirement already satisfied: librosa in /opt/conda/lib/python3.10/site-packages (0.10.2.post1)
# Requirement already satisfied: soundfile in /opt/conda/lib/python3.10/site-packages (0.12.1)
# Requirement already satisfied: audioread>=2.1.9 in /opt/conda/lib/python3.10/site-packages (from librosa) (3.0.1)
# Requirement already satisfied: scipy>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from librosa) (1.14.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /opt/conda/lib/python3.10/site-packages (from librosa) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /opt/conda/lib/python3.10/site-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /opt/conda/lib/python3.10/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in /opt/conda/lib/python3.10/site-packages (from librosa) (0.60.0)
# Requirement already satisfied: pooch>=1.1 in /opt/conda/lib/python3.10/site-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /opt/conda/lib/python3.10/site-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /opt/conda/lib/python3.10/site-packages (from librosa) (4.12.2)
# Requirement already satisfied: lazy-loader>=0.1 in /opt/conda/lib/python3.10/site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /opt/conda/lib/python3.10/site-packages (from librosa) (1.0.8)
# Requirement already satisfied: cffi>=1.0 in /opt/conda/lib/python3.10/site-packages (from soundfile) (1.16.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.0->soundfile) (2.22)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from lazy-loader>=0.1->librosa) (21.3)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /opt/conda/lib/python3.10/site-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /opt/conda/lib/python3.10/site-packages (from pooch>=1.1->librosa) (3.11.0)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/lib/python3.10/site-packages (from pooch>=1.1->librosa) (2.32.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.20.0->librosa) (3.5.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->lazy-loader>=0.1->librosa) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from pydub import AudioSegment
from pydub.silence import split_on_silence
import numpy as np
import librosa

# %%
def denoise_audio(y, sr):
    stft = np.abs(librosa.stft(y))
    noise_thresh = np.mean(stft, axis=1)
    stft_denoised = np.where(stft < noise_thresh[:, None], 0, stft)
    y_denoised = librosa.istft(stft_denoised)
    return y_denoised

# %%
def resample_audio(y, sr, target_sr=16000):
    return librosa.resample(y, orig_sr=sr, target_sr=target_sr), target_sr

# %%
def segment_audio_with_parameters(input_file, min_silence_len, silence_thresh, output_dir='test_segments'):
    y, sr = librosa.load(input_file, sr=None)
    y_denoised = denoise_audio(y, sr)
    y_resampled, target_sr = resample_audio(y_denoised, sr)
    audio = AudioSegment(
        y_resampled.tobytes(), 
        frame_rate=target_sr, 
        sample_width=y_resampled.dtype.itemsize, 
        channels=1
    )

    # Split audio based on specified silence parameters
    segments = split_on_silence(
        audio,
        min_silence_len=min_silence_len,
        silence_thresh=silence_thresh
    )

    # Create a folder based on the input file name within the output directory
    base_name = os.path.splitext(os.path.basename(input_file))[0]
    output_folder = os.path.join(output_dir, base_name)
    os.makedirs(output_folder, exist_ok=True)

    # Save each segment to the folder
    segment_durations = []
    for i, segment in enumerate(segments):
        segment_duration = segment.duration_seconds
        segment_durations.append(segment_duration)

        # Define the output path for each segment
        segment_path = os.path.join(output_folder, f"{base_name}_segment_{i+1}.wav")
        segment.export(segment_path, format="wav")

    # Collect segment info
    results = {
        'file': input_file,
        'min_silence_len': min_silence_len,
        'silence_thresh': silence_thresh,
        'num_segments': len(segments),
        'segment_durations': segment_durations,
        'output_folder': output_folder
    }

    print(f"Processed {input_file} with min_silence_len={min_silence_len}, "
          f"silence_thresh={silence_thresh}: Total Segments = {len(segments)}")
    print(f"Segments saved in {output_folder}")

    return results

# %%
input_file = "/kaggle/input/dataset-nlp/Dataset/English/traffic_0000.wav"
min_silence_len = 100   
silence_thresh = -7    
output_dir = 'segmented_files_output_latest'


single_file_results = segment_audio_with_parameters(input_file, min_silence_len, silence_thresh, output_dir=output_dir)


print(single_file_results)
# Out:
# Processed /kaggle/input/dataset-nlp/Dataset/English/traffic_0000.wav with min_silence_len=100, silence_thresh=-7: Total Segments = 24
# Segments saved in segmented_files_output_latest/traffic_0000
# {'file': '/kaggle/input/dataset-nlp/Dataset/English/traffic_0000.wav', 'min_silence_len': 100, 'silence_thresh': -7, 'num_segments': 24, 'segment_durations': [17.484, 104.485, 43.925, 91.214, 20.894, 6.962, 29.707, 0.426, 0.273, 18.12, 18.935, 14.363, 1.445, 1.702, 8.903, 31.222, 33.246, 4.802, 8.988, 63.137, 5.137, 63.468, 13.091, 0.777], 'output_folder': 'segmented_files_output_latest/traffic_0000'}

# %%
input_file = "/kaggle/input/dataset-nlp/Dataset/English/education_0003.wav"
min_silence_len = 500   
silence_thresh = -10   
output_dir = 'segmented_files_output_latest'


single_file_results = segment_audio_with_parameters(input_file, min_silence_len, silence_thresh, output_dir=output_dir)


print(single_file_results)
# Out:
# Processed /kaggle/input/dataset-nlp/Dataset/English/education_0003.wav with min_silence_len=500, silence_thresh=-10: Total Segments = 105
# Segments saved in segmented_files_output_latest/education_0003
# {'file': '/kaggle/input/dataset-nlp/Dataset/English/education_0003.wav', 'min_silence_len': 500, 'silence_thresh': -10, 'num_segments': 105, 'segment_durations': [6.683, 14.524, 35.673, 3.358, 6.461, 3.26, 7.998, 5.598, 2.303, 2.715, 5.372, 9.596, 169.531, 2.746, 4.991, 5.212, 2.878, 3.327, 4.926, 90.844, 8.926, 13.34, 5.117, 2.942, 3.452, 4.766, 9.243, 5.216, 3.55, 2.429, 3.101, 5.054, 5.499, 6.014, 7.996, 1.95, 7.102, 10.044, 9.692, 18.367, 8.349, 7.517, 5.532, 9.499, 2.974, 1.407, 5.821, 3.998, 4.349, 6.909, 9.148, 8.923, 8.411, 11.58, 3.358, 12.859, 11.838, 7.133, 3.676, 3.647, 4.699, 6.141, 10.653, 9.118, 9.82, 1.722, 3.136, 0.605, 1.309, 1.725, 0.923, 2.271, 4.159, 4.605, 8.029, 9.949, 0.733, 7.195, 5.34, 3.805, 9.406, 7.357, 8.321, 10.332, 8.061, 7.004, 12.541, 7.998, 8.126, 2.878, 4.605, 1.66, 5.79, 6.141, 5.215, 7.776, 7.198, 12.316, 5.82, 8.158, 10.588, 11.133, 4.028, 7.357, 3.518], 'output_folder': 'segmented_files_output_latest/education_0003'}

# %%
input_file = "/kaggle/input/dataset-nlp/Dataset/English/education_0002.wav"
min_silence_len = 500   
silence_thresh = -10   
output_dir = 'segmented_files_output_latest'


single_file_results = segment_audio_with_parameters(input_file, min_silence_len, silence_thresh, output_dir=output_dir)


print(single_file_results)
# Out:
# Processed /kaggle/input/dataset-nlp/Dataset/English/education_0002.wav with min_silence_len=500, silence_thresh=-10: Total Segments = 117
# Segments saved in segmented_files_output_latest/education_0002
# {'file': '/kaggle/input/dataset-nlp/Dataset/English/education_0002.wav', 'min_silence_len': 500, 'silence_thresh': -10, 'num_segments': 117, 'segment_durations': [1.177, 3.29, 0.22, 6.61, 4.817, 2.916, 3.365, 1.047, 29.562, 1.342, 17.638, 9.346, 5.11, 3.486, 6.429, 6.561, 16.402, 6.071, 9.373, 2.545, 6.327, 1.088, 4.019, 3.206, 1.738, 8.991, 4.927, 15.823, 2.213, 0.652, 0.221, 1.911, 0.669, 1.854, 9.656, 18.912, 9.476, 1.59, 0.664, 5.982, 12.475, 4.987, 2.311, 9.511, 13.465, 13.029, 9.806, 0.536, 20.893, 5.294, 13.477, 4.512, 2.407, 3.193, 3.079, 1.706, 5.565, 4.902, 12.171, 18.979, 15.032, 9.503, 0.274, 7.686, 24.402, 14.57, 5.852, 2.635, 2.393, 3.645, 1.5, 6.759, 5.532, 0.279, 2.365, 10.406, 3.333, 6.552, 7.116, 6.583, 2.749, 5.462, 0.545, 4.182, 3.896, 2.095, 10.297, 16.128, 0.769, 5.224, 6.365, 2.547, 5.555, 0.861, 33.674, 1.985, 7.746, 55.017, 18.238, 18.164, 4.854, 4.72, 15.864, 2.58, 32.91, 8.772, 2.465, 11.325, 24.829, 21.512, 17.551, 2.561, 24.188, 13.156, 15.894, 0.252, 3.466], 'output_folder': 'segmented_files_output_latest/education_0002'}

# %%
input_file = "/kaggle/input/dataset-nlp/Dataset/English/education_0001.wav"
min_silence_len = 100   
silence_thresh = -10   
output_dir = 'segmented_files_output_latest'


single_file_results = segment_audio_with_parameters(input_file, min_silence_len, silence_thresh, output_dir=output_dir)


print(single_file_results)
# Out:
# Processed /kaggle/input/dataset-nlp/Dataset/English/education_0001.wav with min_silence_len=100, silence_thresh=-10: Total Segments = 106
# Segments saved in segmented_files_output_latest/education_0001
# {'file': '/kaggle/input/dataset-nlp/Dataset/English/education_0001.wav', 'min_silence_len': 100, 'silence_thresh': -10, 'num_segments': 106, 'segment_durations': [6.941, 0.25, 0.861, 0.285, 0.314, 0.973, 0.208, 2.717, 1.338, 4.893, 4.797, 3.453, 2.975, 0.414, 0.347, 6.811, 2.906, 2.81, 0.301, 0.557, 11.037, 2.238, 0.252, 2.113, 0.541, 0.282, 0.253, 0.24, 21.12, 49.295, 95.457, 27.775, 3.169, 29.629, 0.621, 29.648, 24.637, 28.205, 15.949, 17.644, 18.766, 17.982, 3.293, 17.946, 65.755, 0.333, 13.968, 8.64, 16.144, 1.52, 26.08, 19.968, 34.112, 38.48, 0.685, 8.637, 1.466, 23.725, 4.653, 42.874, 0.282, 28.986, 13.692, 34.253, 4.877, 5.15, 0.336, 8.107, 1.53, 4.026, 11.194, 16.142, 19.501, 10.093, 0.72, 1.6, 1.184, 54.88, 32.637, 11.483, 1.786, 12.509, 13.071, 13.007, 43.18, 3.79, 1.837, 7.917, 2.412, 4.145, 29.408, 0.256, 4.957, 19.994, 18.669, 13.581, 1.501, 0.272, 1.872, 0.192, 1.117, 2.588, 17.601, 4.799, 23.137, 14.432], 'output_folder': 'segmented_files_output_latest/education_0001'}

# %%
#!zip -r L1Segmentation.zip /kaggle/working/segmented_files_output_latest

# %% [markdown]
# # Code Mixed

# %%
import os
import numpy as np
import librosa
from pydub import AudioSegment
from pydub.silence import split_on_silence

def segment_audio(input_file, min_silence_len=2000, silence_thresh=-30, keep_silence=200, output_dir='segments'):
    # Load audio file
    audio = AudioSegment.from_file(input_file)
    
    # Split audio based on silence
    segments = split_on_silence(
        audio,
        min_silence_len=min_silence_len,  # Minimum silence length in ms
        silence_thresh=silence_thresh       # Silence threshold in dBFS (decibels relative to full scale)
    )
    
    # Create output directory for the file if not exists
    file_name = os.path.splitext(os.path.basename(input_file))[0]
    file_output_dir = os.path.join(output_dir, file_name)
    if not os.path.exists(file_output_dir):
        os.makedirs(file_output_dir)
    
    # Export each segment as a separate file after denoising
    for i, segment in enumerate(segments):
        # Convert the segment to a numpy array for denoising
        y = np.array(segment.get_array_of_samples()).astype(np.float32)  # Ensure it's float32
        y /= np.max(np.abs(y))  # Normalize to range [-1.0, 1.0]
        sr = segment.frame_rate
        
        # Denoise the audio segment
        y_denoised = denoise_audio(y, sr)
        
        # Convert back to AudioSegment
        denoised_segment = AudioSegment(
            (y_denoised * 32767).astype(np.int16).tobytes(),  # Convert back to int16 for AudioSegment
            frame_rate=sr,
            sample_width=2,  # 2 bytes for int16
            channels=segment.channels
        )
        
        # Export the denoised segment
        denoised_segment.export(os.path.join(file_output_dir, f'segment_{i+1}.wav'), format="wav")
    
    print(f"Processed {input_file}: Total Segments = {len(segments)}")
    return len(segments), [seg.duration_seconds for seg in segments]

def denoise_audio(y, sr):
    stft = np.abs(librosa.stft(y))
    noise_thresh = np.mean(stft, axis=1)
    stft_denoised = np.where(stft < noise_thresh[:, None], 0, stft)
    y_denoised = librosa.istft(stft_denoised)
    
    return y_denoised.astype(np.float32)  # Ensure the output is in float32 format

# %%
input_file = "/kaggle/input/dataset-nlp/Dataset/CodeMixed/0RDwoEVIUAhVPibN.wav"
min_silence_len = 2000 
silence_thresh = -30
output_dir = 'segmented_files_output_latest'


single_file_results = segment_audio(input_file, min_silence_len, silence_thresh, output_dir=output_dir)


print(single_file_results)
# Out:
# Processed /kaggle/input/dataset-nlp/Dataset/CodeMixed/0RDwoEVIUAhVPibN.wav: Total Segments = 60
# (60, [52.96, 5.58, 2.491, 7.22, 4.609, 2.064, 7.665, 0.942, 1.141, 4.506, 7.376, 3.653, 2.061, 27.403, 4.737, 0.75, 3.492, 10.9, 2.811, 0.535, 7.461, 4.997, 2.253, 12.266, 3.016, 11.427, 4.562, 16.404, 8.099, 5.537, 1.377, 0.66, 8.965, 21.613, 3.687, 1.021, 3.74, 0.749, 4.416, 7.709, 7.798, 0.883, 1.289, 2.811, 0.203, 2.673, 0.795, 2.925, 0.255, 11.687, 2.233, 19.511, 1.437, 9.064, 9.299, 16.273, 1.696, 2.035, 2.748, 28.601])

# %%
input_file = "/kaggle/input/dataset-nlp/Dataset/CodeMixed/0RmUBH81UE6b1jFc.wav"
min_silence_len = 2000 
silence_thresh = -30
output_dir = 'segmented_files_output_latest'


single_file_results = segment_audio(input_file, min_silence_len, silence_thresh, output_dir=output_dir)


print(single_file_results)
# Out:
# Processed /kaggle/input/dataset-nlp/Dataset/CodeMixed/0RmUBH81UE6b1jFc.wav: Total Segments = 49
# (49, [4.073, 6.885, 9.249, 9.764, 12.744, 5.498, 12.776, 4.065, 3.539, 8.313, 7.09, 33.422, 11.402, 7.788, 9.61, 5.672, 5.738, 5.976, 4.804, 5.071, 2.051, 0.95, 1.971, 13.313, 6.769, 6.775, 3.171, 10.562, 8.394, 2.514, 2.434, 15.449, 1.662, 5.144, 4.143, 16.679, 4.738, 4.13, 18.463, 15.299, 7.32, 7.383, 15.64, 2.142, 17.401, 30.831, 3.543, 3.997, 2.234])

# %%
input_file = "/kaggle/input/dataset-nlp/Dataset/CodeMixed/0V7yPA2pAqrJrW7Y.wav"
min_silence_len = 2000 
silence_thresh = -30
output_dir = 'segmented_files_output_latest'


single_file_results = segment_audio(input_file, min_silence_len, silence_thresh, output_dir=output_dir)


print(single_file_results)
# Out:
# Processed /kaggle/input/dataset-nlp/Dataset/CodeMixed/0V7yPA2pAqrJrW7Y.wav: Total Segments = 13
# (13, [32.859, 14.16, 2.504, 69.91, 66.942, 3.894, 4.965, 9.012, 8.905, 16.764, 3.911, 34.262, 51.858])

# %%
input_file = "/kaggle/input/dataset-nlp/Dataset/CodeMixed/0ZCBRzDx7vigtAuy.wav"
min_silence_len = 2000 
silence_thresh = -30 
output_dir = 'segmented_files_output_latest'


single_file_results = segment_audio(input_file, min_silence_len, silence_thresh, output_dir=output_dir)


print(single_file_results)
# Out:
# Processed /kaggle/input/dataset-nlp/Dataset/CodeMixed/0ZCBRzDx7vigtAuy.wav: Total Segments = 18
# (18, [159.107, 125.04, 18.264, 7.544, 18.501, 12.391, 14.419, 15.513, 1.895, 41.507, 3.617, 9.672, 4.36, 3.116, 12.944, 42.881, 76.549, 41.909])

# %%
input_file = "/kaggle/input/dataset-nlp/Dataset/CodeMixed/0a8GyoWn0KRgXxTx.wav"
min_silence_len = 2000 
silence_thresh = -30 
output_dir = 'segmented_files_output_latest'


single_file_results = segment_audio(input_file, min_silence_len, silence_thresh, output_dir=output_dir)


print(single_file_results)
# Out:
# Processed /kaggle/input/dataset-nlp/Dataset/CodeMixed/0a8GyoWn0KRgXxTx.wav: Total Segments = 16
# (16, [13.782, 10.985, 24.686, 13.851, 35.902, 4.553, 29.027, 4.431, 5.671, 22.588, 47.573, 29.787, 44.246, 10.181, 45.465, 45.762])

# %%
input_file = "/kaggle/input/dataset-nlp/Dataset/CodeMixed/0jdhCdy6wPFMjRXl.wav"
min_silence_len = 2000 
silence_thresh = -30 
output_dir = 'segmented_files_output_latest'


single_file_results = segment_audio(input_file, min_silence_len, silence_thresh, output_dir=output_dir)


print(single_file_results)
# Out:
# Processed /kaggle/input/dataset-nlp/Dataset/CodeMixed/0jdhCdy6wPFMjRXl.wav: Total Segments = 25
# (25, [41.569, 26.475, 81.572, 55.052, 26.5, 30.233, 10.076, 9.041, 2.432, 45.366, 8.671, 26.455, 9.021, 11.081, 17.195, 27.428, 11.065, 2.197, 43.649, 25.362, 1.459, 5.927, 21.6, 2.151, 5.994])

# %%
input_file = "/kaggle/input/dataset-nlp/Dataset/CodeMixed/0ypaM0qtYiXXTroM.wav"
min_silence_len = 2000 
silence_thresh = -30 
output_dir = 'segmented_files_output_latest'


single_file_results = segment_audio(input_file, min_silence_len, silence_thresh, output_dir=output_dir)


print(single_file_results)
# Out:
# Processed /kaggle/input/dataset-nlp/Dataset/CodeMixed/0ypaM0qtYiXXTroM.wav: Total Segments = 10
# (10, [3.812, 0.338, 4.621, 0.411, 0.881, 1.263, 0.212, 2.93, 2.806, 0.209])

# %%
# !zip -r L1Segmentation-Nov.zip /kaggle/working/segmented_files_output_latest
# Out:
#   adding: kaggle/working/segmented_files_output_latest/ (stored 0%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/ (stored 0%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_18.wav (deflated 31%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_31.wav (deflated 15%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_54.wav (deflated 28%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_47.wav (deflated 19%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_15.wav (deflated 24%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_60.wav (deflated 24%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_58.wav (deflated 21%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_5.wav (deflated 32%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_12.wav (deflated 31%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_39.wav (deflated 24%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_1.wav (deflated 27%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_26.wav (deflated 31%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_30.wav (deflated 36%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_7.wav (deflated 37%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_24.wav (deflated 41%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_16.wav (deflated 14%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_23.wav (deflated 18%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_11.wav (deflated 35%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_59.wav (deflated 21%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_17.wav (deflated 55%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_46.wav (deflated 19%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_28.wav (deflated 35%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_48.wav (deflated 25%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_44.wav (deflated 25%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_52.wav (deflated 28%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_13.wav (deflated 22%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_4.wav (deflated 28%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_2.wav (deflated 23%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_45.wav (deflated 18%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_51.wav (deflated 22%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_57.wav (deflated 18%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_38.wav (deflated 20%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_53.wav (deflated 19%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_29.wav (deflated 39%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_34.wav (deflated 40%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_36.wav (deflated 22%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_19.wav (deflated 31%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_3.wav (deflated 18%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_50.wav (deflated 54%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_35.wav (deflated 34%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_20.wav (deflated 18%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_25.wav (deflated 21%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_32.wav (deflated 49%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_8.wav (deflated 18%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_22.wav (deflated 30%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_6.wav (deflated 20%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_33.wav (deflated 34%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_41.wav (deflated 40%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_42.wav (deflated 17%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_40.wav (deflated 25%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_43.wav (deflated 32%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_56.wav (deflated 37%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_37.wav (deflated 35%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_10.wav (deflated 40%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_14.wav (deflated 28%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_21.wav (deflated 26%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_27.wav (deflated 25%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_9.wav (deflated 19%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_55.wav (deflated 28%)
#   adding: kaggle/working/segmented_files_output_latest/0RDwoEVIUAhVPibN/segment_49.wav (deflated 20%)
#   adding: kaggle/working/segmented_files_output_latest/0ZCBRzDx7vigtAuy/ (stored 0%)
#   adding: kaggle/working/segmented_files_output_latest/0ZCBRzDx7vigtAuy/segment_18.wav (deflated 31%)
#   adding: kaggle/working/segmented_files_output_latest/0ZCBRzDx7vigtAuy/segment_15.wav (deflated 41%)
#   adding: kaggle/working/segmented_files_output_latest/0ZCBRzDx7vigtAuy/segment_5.wav (deflated 38%)
#   adding: kaggle/working/segmented_files_output_latest/0ZCBRzDx7vigtAuy/segment_12.wav (deflated 37%)
#   adding: kaggle/working/segmented_files_output_latest/0ZCBRzDx7vigtAuy/segment_1.wav (deflated 33%)
#   adding: kaggle/working/segmented_files_output_latest/0ZCBRzDx7vigtAuy/segment_7.wav (deflated 41%)
#   adding: kaggle/working/segmented_files_output_latest/0ZCBRzDx7vigtAuy/segment_16.wav (deflated 38%)
#   adding: kaggle/working/segmented_files_output_latest/0ZCBRzDx7vigtAuy/segment_11.wav (deflated 23%)
#   adding: kaggle/working/segmented_files_output_latest/0ZCBRzDx7vigtAuy/segment_17.wav (deflated 38%)
#   adding: kaggle/working/segmented_files_output_latest/0ZCBRzDx7vigtAuy/segment_13.wav (deflated 39%)
#   adding: kaggle/working/segmented_files_output_latest/0ZCBRzDx7vigtAuy/segment_4.wav (deflated 35%)
#   adding: kaggle/working/segmented_files_output_latest/0ZCBRzDx7vigtAuy/segment_2.wav (deflated 39%)
#   adding: kaggle/working/segmented_files_output_latest/0ZCBRzDx7vigtAuy/segment_3.wav (deflated 40%)
#   adding: kaggle/working/segmented_files_output_latest/0ZCBRzDx7vigtAuy/segment_8.wav (deflated 33%)
#   adding: kaggle/working/segmented_files_output_latest/0ZCBRzDx7vigtAuy/segment_6.wav (deflated 41%)
#   adding: kaggle/working/segmented_files_output_latest/0ZCBRzDx7vigtAuy/segment_10.wav (deflated 37%)
#   adding: kaggle/working/segmented_files_output_latest/0ZCBRzDx7vigtAuy/segment_14.wav (deflated 43%)
#   adding: kaggle/working/segmented_files_output_latest/0ZCBRzDx7vigtAuy/segment_9.wav (deflated 21%)
#   adding: kaggle/working/segmented_files_output_latest/traffic_0000/ (stored 0%)
#   adding: kaggle/working/segmented_files_output_latest/traffic_0000/traffic_0000_segment_22.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/traffic_0000/traffic_0000_segment_20.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/traffic_0000/traffic_0000_segment_11.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/traffic_0000/traffic_0000_segment_2.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/traffic_0000/traffic_0000_segment_21.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/traffic_0000/traffic_0000_segment_6.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/traffic_0000/traffic_0000_segment_10.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/traffic_0000/traffic_0000_segment_4.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/traffic_0000/traffic_0000_segment_9.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/traffic_0000/traffic_0000_segment_24.wav (deflated 6%)
#   adding: kaggle/working/segmented_files_output_latest/traffic_0000/traffic_0000_segment_17.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/traffic_0000/traffic_0000_segment_23.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/traffic_0000/traffic_0000_segment_5.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/traffic_0000/traffic_0000_segment_18.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/traffic_0000/traffic_0000_segment_7.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/traffic_0000/traffic_0000_segment_8.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/traffic_0000/traffic_0000_segment_1.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/traffic_0000/traffic_0000_segment_3.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/traffic_0000/traffic_0000_segment_19.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/traffic_0000/traffic_0000_segment_13.wav (deflated 6%)
#   adding: kaggle/working/segmented_files_output_latest/traffic_0000/traffic_0000_segment_14.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/traffic_0000/traffic_0000_segment_16.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/traffic_0000/traffic_0000_segment_15.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/traffic_0000/traffic_0000_segment_12.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/ (stored 0%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_80.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_11.wav (deflated 12%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_95.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_5.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_16.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_38.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_45.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_10.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_9.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_18.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_60.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_105.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_15.wav (deflated 10%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_25.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_8.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_87.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_89.wav (deflated 10%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_57.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_96.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_19.wav (deflated 11%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_53.wav (deflated 10%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_55.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_72.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_85.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_91.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_2.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_28.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_1.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_23.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_41.wav (deflated 10%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_86.wav (deflated 11%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_76.wav (deflated 11%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_3.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_103.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_33.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_81.wav (deflated 10%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_104.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_98.wav (deflated 11%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_62.wav (deflated 13%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_90.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_68.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_22.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_27.wav (deflated 13%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_102.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_35.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_66.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_40.wav (deflated 10%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_49.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_63.wav (deflated 10%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_34.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_74.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_42.wav (deflated 10%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_31.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_30.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_82.wav (deflated 12%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_36.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_84.wav (deflated 10%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_24.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_47.wav (deflated 10%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_7.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_51.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_52.wav (deflated 11%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_48.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_14.wav (deflated 10%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_13.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_54.wav (deflated 10%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_58.wav (deflated 11%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_67.wav (deflated 13%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_94.wav (deflated 11%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_78.wav (deflated 10%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_29.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_37.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_79.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_59.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_20.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_93.wav (deflated 10%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_75.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_32.wav (deflated 10%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_83.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_92.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_44.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_46.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_26.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_88.wav (deflated 10%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_101.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_43.wav (deflated 13%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_100.wav (deflated 10%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_69.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_97.wav (deflated 10%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_65.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_50.wav (deflated 12%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_12.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_21.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_99.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_64.wav (deflated 10%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_77.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_61.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_17.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_70.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_4.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_39.wav (deflated 11%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_73.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_56.wav (deflated 10%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_6.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0003/education_0003_segment_71.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/ (stored 0%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_18.wav (deflated 39%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_31.wav (deflated 16%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_47.wav (deflated 32%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_15.wav (deflated 40%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_5.wav (deflated 35%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_12.wav (deflated 35%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_39.wav (deflated 41%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_1.wav (deflated 34%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_26.wav (deflated 24%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_30.wav (deflated 22%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_7.wav (deflated 42%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_24.wav (deflated 33%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_16.wav (deflated 28%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_23.wav (deflated 17%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_11.wav (deflated 23%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_17.wav (deflated 34%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_46.wav (deflated 28%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_28.wav (deflated 28%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_48.wav (deflated 27%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_44.wav (deflated 16%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_13.wav (deflated 35%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_4.wav (deflated 35%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_2.wav (deflated 26%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_45.wav (deflated 32%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_38.wav (deflated 24%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_29.wav (deflated 35%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_34.wav (deflated 25%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_36.wav (deflated 32%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_19.wav (deflated 27%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_3.wav (deflated 43%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_35.wav (deflated 30%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_20.wav (deflated 31%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_25.wav (deflated 25%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_32.wav (deflated 39%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_8.wav (deflated 44%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_22.wav (deflated 17%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_6.wav (deflated 19%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_33.wav (deflated 16%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_41.wav (deflated 38%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_42.wav (deflated 30%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_40.wav (deflated 40%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_43.wav (deflated 43%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_37.wav (deflated 33%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_10.wav (deflated 29%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_14.wav (deflated 33%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_21.wav (deflated 15%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_27.wav (deflated 36%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_9.wav (deflated 24%)
#   adding: kaggle/working/segmented_files_output_latest/0RmUBH81UE6b1jFc/segment_49.wav (deflated 25%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/ (stored 0%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_75.wav (deflated 25%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_22.wav (deflated 11%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_101.wav (deflated 14%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_44.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_99.wav (deflated 11%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_12.wav (deflated 10%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_52.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_18.wav (deflated 11%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_9.wav (deflated 14%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_72.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_70.wav (deflated 10%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_100.wav (deflated 47%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_81.wav (deflated 13%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_93.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_51.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_88.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_10.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_48.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_14.wav (deflated 39%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_66.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_60.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_27.wav (deflated 41%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_13.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_77.wav (deflated 12%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_17.wav (deflated 10%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_32.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_67.wav (deflated 40%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_37.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_39.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_54.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_34.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_19.wav (deflated 40%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_8.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_68.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_24.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_95.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_63.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_11.wav (deflated 10%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_85.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_53.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_31.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_97.wav (deflated 14%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_6.wav (deflated 20%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_42.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_89.wav (deflated 11%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_83.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_58.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_84.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_103.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_50.wav (deflated 14%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_41.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_102.wav (deflated 12%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_94.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_28.wav (deflated 37%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_87.wav (deflated 13%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_90.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_79.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_47.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_2.wav (deflated 59%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_1.wav (deflated 10%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_15.wav (deflated 39%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_105.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_55.wav (deflated 22%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_69.wav (deflated 14%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_92.wav (deflated 29%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_4.wav (deflated 37%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_91.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_64.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_49.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_62.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_21.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_40.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_30.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_45.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_33.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_73.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_25.wav (deflated 25%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_43.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_26.wav (deflated 46%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_86.wav (deflated 10%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_16.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_74.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_56.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_82.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_35.wav (deflated 26%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_80.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_71.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_29.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_5.wav (deflated 42%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_57.wav (deflated 14%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_38.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_96.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_78.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_106.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_36.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_7.wav (deflated 51%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_23.wav (deflated 40%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_104.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_59.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_76.wav (deflated 13%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_46.wav (deflated 43%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_3.wav (deflated 16%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_65.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_20.wav (deflated 26%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_98.wav (deflated 34%)
#   adding: kaggle/working/segmented_files_output_latest/education_0001/education_0001_segment_61.wav (deflated 47%)
#   adding: kaggle/working/segmented_files_output_latest/0a8GyoWn0KRgXxTx/ (stored 0%)
#   adding: kaggle/working/segmented_files_output_latest/0a8GyoWn0KRgXxTx/segment_15.wav (deflated 24%)
#   adding: kaggle/working/segmented_files_output_latest/0a8GyoWn0KRgXxTx/segment_5.wav (deflated 35%)
#   adding: kaggle/working/segmented_files_output_latest/0a8GyoWn0KRgXxTx/segment_12.wav (deflated 35%)
#   adding: kaggle/working/segmented_files_output_latest/0a8GyoWn0KRgXxTx/segment_1.wav (deflated 31%)
#   adding: kaggle/working/segmented_files_output_latest/0a8GyoWn0KRgXxTx/segment_7.wav (deflated 33%)
#   adding: kaggle/working/segmented_files_output_latest/0a8GyoWn0KRgXxTx/segment_16.wav (deflated 24%)
#   adding: kaggle/working/segmented_files_output_latest/0a8GyoWn0KRgXxTx/segment_11.wav (deflated 26%)
#   adding: kaggle/working/segmented_files_output_latest/0a8GyoWn0KRgXxTx/segment_13.wav (deflated 31%)
#   adding: kaggle/working/segmented_files_output_latest/0a8GyoWn0KRgXxTx/segment_4.wav (deflated 27%)
#   adding: kaggle/working/segmented_files_output_latest/0a8GyoWn0KRgXxTx/segment_2.wav (deflated 26%)
#   adding: kaggle/working/segmented_files_output_latest/0a8GyoWn0KRgXxTx/segment_3.wav (deflated 25%)
#   adding: kaggle/working/segmented_files_output_latest/0a8GyoWn0KRgXxTx/segment_8.wav (deflated 31%)
#   adding: kaggle/working/segmented_files_output_latest/0a8GyoWn0KRgXxTx/segment_6.wav (deflated 21%)
#   adding: kaggle/working/segmented_files_output_latest/0a8GyoWn0KRgXxTx/segment_10.wav (deflated 28%)
#   adding: kaggle/working/segmented_files_output_latest/0a8GyoWn0KRgXxTx/segment_14.wav (deflated 23%)
#   adding: kaggle/working/segmented_files_output_latest/0a8GyoWn0KRgXxTx/segment_9.wav (deflated 23%)
#   adding: kaggle/working/segmented_files_output_latest/0ypaM0qtYiXXTroM/ (stored 0%)
#   adding: kaggle/working/segmented_files_output_latest/0ypaM0qtYiXXTroM/segment_5.wav (deflated 16%)
#   adding: kaggle/working/segmented_files_output_latest/0ypaM0qtYiXXTroM/segment_1.wav (deflated 45%)
#   adding: kaggle/working/segmented_files_output_latest/0ypaM0qtYiXXTroM/segment_7.wav (deflated 14%)
#   adding: kaggle/working/segmented_files_output_latest/0ypaM0qtYiXXTroM/segment_4.wav (deflated 14%)
#   adding: kaggle/working/segmented_files_output_latest/0ypaM0qtYiXXTroM/segment_2.wav (deflated 16%)
#   adding: kaggle/working/segmented_files_output_latest/0ypaM0qtYiXXTroM/segment_3.wav (deflated 29%)
#   adding: kaggle/working/segmented_files_output_latest/0ypaM0qtYiXXTroM/segment_8.wav (deflated 21%)
#   adding: kaggle/working/segmented_files_output_latest/0ypaM0qtYiXXTroM/segment_6.wav (deflated 20%)
#   adding: kaggle/working/segmented_files_output_latest/0ypaM0qtYiXXTroM/segment_10.wav (deflated 13%)
#   adding: kaggle/working/segmented_files_output_latest/0ypaM0qtYiXXTroM/segment_9.wav (deflated 29%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/ (stored 0%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_96.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_40.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_79.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_65.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_3.wav (deflated 26%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_13.wav (deflated 12%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_89.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_54.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_98.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_62.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_55.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_28.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_100.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_103.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_43.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_77.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_86.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_32.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_25.wav (deflated 10%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_104.wav (deflated 20%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_88.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_31.wav (deflated 11%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_110.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_38.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_87.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_46.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_26.wav (deflated 12%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_6.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_29.wav (deflated 18%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_20.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_48.wav (deflated 20%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_4.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_82.wav (deflated 10%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_116.wav (deflated 12%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_60.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_57.wav (deflated 12%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_9.wav (deflated 11%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_101.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_107.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_90.wav (deflated 11%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_18.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_39.wav (deflated 31%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_45.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_35.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_44.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_113.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_114.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_75.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_71.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_95.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_97.wav (deflated 11%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_73.wav (deflated 11%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_30.wav (deflated 32%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_22.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_112.wav (deflated 10%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_63.wav (deflated 40%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_51.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_5.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_61.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_67.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_99.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_27.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_106.wav (deflated 11%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_17.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_115.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_15.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_34.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_80.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_69.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_59.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_78.wav (deflated 10%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_74.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_53.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_52.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_64.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_37.wav (deflated 10%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_108.wav (deflated 10%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_84.wav (deflated 10%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_66.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_83.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_11.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_81.wav (deflated 11%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_33.wav (deflated 13%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_70.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_7.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_92.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_36.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_85.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_117.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_10.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_109.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_8.wav (deflated 35%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_49.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_21.wav (deflated 10%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_16.wav (deflated 10%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_102.wav (deflated 11%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_14.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_56.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_50.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_42.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_47.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_72.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_23.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_12.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_19.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_76.wav (deflated 8%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_24.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_1.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_105.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_58.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_2.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_91.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_111.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_93.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_41.wav (deflated 9%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_68.wav (deflated 7%)
#   adding: kaggle/working/segmented_files_output_latest/education_0002/education_0002_segment_94.wav (deflated 10%)
#   adding: kaggle/working/segmented_files_output_latest/0V7yPA2pAqrJrW7Y/ (stored 0%)
#   adding: kaggle/working/segmented_files_output_latest/0V7yPA2pAqrJrW7Y/segment_5.wav (deflated 44%)
#   adding: kaggle/working/segmented_files_output_latest/0V7yPA2pAqrJrW7Y/segment_12.wav (deflated 38%)
#   adding: kaggle/working/segmented_files_output_latest/0V7yPA2pAqrJrW7Y/segment_1.wav (deflated 33%)
#   adding: kaggle/working/segmented_files_output_latest/0V7yPA2pAqrJrW7Y/segment_7.wav (deflated 26%)
#   adding: kaggle/working/segmented_files_output_latest/0V7yPA2pAqrJrW7Y/segment_11.wav (deflated 21%)
#   adding: kaggle/working/segmented_files_output_latest/0V7yPA2pAqrJrW7Y/segment_13.wav (deflated 38%)
#   adding: kaggle/working/segmented_files_output_latest/0V7yPA2pAqrJrW7Y/segment_4.wav (deflated 42%)
#   adding: kaggle/working/segmented_files_output_latest/0V7yPA2pAqrJrW7Y/segment_2.wav (deflated 30%)
#   adding: kaggle/working/segmented_files_output_latest/0V7yPA2pAqrJrW7Y/segment_3.wav (deflated 21%)
#   adding: kaggle/working/segmented_files_output_latest/0V7yPA2pAqrJrW7Y/segment_8.wav (deflated 37%)
#   adding: kaggle/working/segmented_files_output_latest/0V7yPA2pAqrJrW7Y/segment_6.wav (deflated 27%)
#   adding: kaggle/working/segmented_files_output_latest/0V7yPA2pAqrJrW7Y/segment_10.wav (deflated 37%)
#   adding: kaggle/working/segmented_files_output_latest/0V7yPA2pAqrJrW7Y/segment_9.wav (deflated 37%)
#   adding: kaggle/working/segmented_files_output_latest/0jdhCdy6wPFMjRXl/ (stored 0%)
#   adding: kaggle/working/segmented_files_output_latest/0jdhCdy6wPFMjRXl/segment_18.wav (deflated 27%)
#   adding: kaggle/working/segmented_files_output_latest/0jdhCdy6wPFMjRXl/segment_15.wav (deflated 37%)
#   adding: kaggle/working/segmented_files_output_latest/0jdhCdy6wPFMjRXl/segment_5.wav (deflated 40%)
#   adding: kaggle/working/segmented_files_output_latest/0jdhCdy6wPFMjRXl/segment_12.wav (deflated 36%)
#   adding: kaggle/working/segmented_files_output_latest/0jdhCdy6wPFMjRXl/segment_1.wav (deflated 36%)
#   adding: kaggle/working/segmented_files_output_latest/0jdhCdy6wPFMjRXl/segment_7.wav (deflated 43%)
#   adding: kaggle/working/segmented_files_output_latest/0jdhCdy6wPFMjRXl/segment_24.wav (deflated 18%)
#   adding: kaggle/working/segmented_files_output_latest/0jdhCdy6wPFMjRXl/segment_16.wav (deflated 39%)
#   adding: kaggle/working/segmented_files_output_latest/0jdhCdy6wPFMjRXl/segment_23.wav (deflated 29%)
#   adding: kaggle/working/segmented_files_output_latest/0jdhCdy6wPFMjRXl/segment_11.wav (deflated 25%)
#   adding: kaggle/working/segmented_files_output_latest/0jdhCdy6wPFMjRXl/segment_17.wav (deflated 36%)
#   adding: kaggle/working/segmented_files_output_latest/0jdhCdy6wPFMjRXl/segment_13.wav (deflated 41%)
#   adding: kaggle/working/segmented_files_output_latest/0jdhCdy6wPFMjRXl/segment_4.wav (deflated 35%)
#   adding: kaggle/working/segmented_files_output_latest/0jdhCdy6wPFMjRXl/segment_2.wav (deflated 35%)
#   adding: kaggle/working/segmented_files_output_latest/0jdhCdy6wPFMjRXl/segment_19.wav (deflated 38%)
#   adding: kaggle/working/segmented_files_output_latest/0jdhCdy6wPFMjRXl/segment_3.wav (deflated 34%)
#   adding: kaggle/working/segmented_files_output_latest/0jdhCdy6wPFMjRXl/segment_20.wav (deflated 37%)
#   adding: kaggle/working/segmented_files_output_latest/0jdhCdy6wPFMjRXl/segment_25.wav (deflated 35%)
#   adding: kaggle/working/segmented_files_output_latest/0jdhCdy6wPFMjRXl/segment_8.wav (deflated 31%)
#   adding: kaggle/working/segmented_files_output_latest/0jdhCdy6wPFMjRXl/segment_22.wav (deflated 25%)
#   adding: kaggle/working/segmented_files_output_latest/0jdhCdy6wPFMjRXl/segment_6.wav (deflated 34%)
#   adding: kaggle/working/segmented_files_output_latest/0jdhCdy6wPFMjRXl/segment_10.wav (deflated 39%)
#   adding: kaggle/working/segmented_files_output_latest/0jdhCdy6wPFMjRXl/segment_14.wav (deflated 35%)
#   adding: kaggle/working/segmented_files_output_latest/0jdhCdy6wPFMjRXl/segment_21.wav (deflated 19%)
#   adding: kaggle/working/segmented_files_output_latest/0jdhCdy6wPFMjRXl/segment_9.wav (deflated 28%)
