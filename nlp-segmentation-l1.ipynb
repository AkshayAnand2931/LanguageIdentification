# %%
# %pip install numpy pydub librosa soundfile
# Out:
# Requirement already satisfied: numpy in c:\users\aksha\appdata\local\programs\python\python39\lib\site-packages (2.0.2)
# Requirement already satisfied: pydub in c:\users\aksha\appdata\local\programs\python\python39\lib\site-packages (0.25.1)
# Requirement already satisfied: librosa in c:\users\aksha\appdata\local\programs\python\python39\lib\site-packages (0.10.2.post1)
# Requirement already satisfied: soundfile in c:\users\aksha\appdata\local\programs\python\python39\lib\site-packages (0.12.1)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\aksha\appdata\roaming\python\python39\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\aksha\appdata\local\programs\python\python39\lib\site-packages (from librosa) (3.0.1)
# Requirement already satisfied: pooch>=1.1 in c:\users\aksha\appdata\local\programs\python\python39\lib\site-packages (from librosa) (1.8.2)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\aksha\appdata\roaming\python\python39\site-packages (from librosa) (4.12.2)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\aksha\appdata\local\programs\python\python39\lib\site-packages (from librosa) (1.13.1)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\aksha\appdata\local\programs\python\python39\lib\site-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: lazy-loader>=0.1 in c:\users\aksha\appdata\local\programs\python\python39\lib\site-packages (from librosa) (0.4)
# Requirement already satisfied: numba>=0.51.0 in c:\users\aksha\appdata\local\programs\python\python39\lib\site-packages (from librosa) (0.60.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\aksha\appdata\local\programs\python\python39\lib\site-packages (from librosa) (1.5.2)
# Requirement already satisfied: joblib>=0.14 in c:\users\aksha\appdata\local\programs\python\python39\lib\site-packages (from librosa) (1.4.2)
# Requirement already satisfied: msgpack>=1.0 in c:\users\aksha\appdata\local\programs\python\python39\lib\site-packages (from librosa) (1.1.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\aksha\appdata\local\programs\python\python39\lib\site-packages (from soundfile) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\aksha\appdata\local\programs\python\python39\lib\site-packages (from cffi>=1.0->soundfile) (2.22)
# Requirement already satisfied: packaging in c:\users\aksha\appdata\roaming\python\python39\site-packages (from lazy-loader>=0.1->librosa) (24.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\aksha\appdata\local\programs\python\python39\lib\site-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\aksha\appdata\local\programs\python\python39\lib\site-packages (from pooch>=1.1->librosa) (2.32.3)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\aksha\appdata\roaming\python\python39\site-packages (from pooch>=1.1->librosa) (4.3.6)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\aksha\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn>=0.20.0->librosa) (3.5.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aksha\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aksha\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2024.8.30)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aksha\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aksha\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.10)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 24.2 is available.
# You should consider upgrading via the 'c:\Users\aksha\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import os
from pydub import AudioSegment
from pydub.silence import split_on_silence
import numpy as np
import librosa

# %%
def read_dataset_folder(dataset_folder):
    audio_files = {'English': [], 'Hindi': [], 'CodeMixed': []}

    for language in ['English', 'Hindi', 'CodeMixed']:
        language_folder = os.path.join(dataset_folder, language)
        for file_name in os.listdir(language_folder):
            if file_name.endswith('.wav'):
                file_path = os.path.join(language_folder, file_name)
                if language == 'English':
                    audio_files['English'].append(file_path)
                elif language == 'Hindi':
                    audio_files['Hindi'].append(file_path)
                elif language == 'CodeMixed':
                    audio_files['CodeMixed'].append(file_path)
    return audio_files

# %%
def denoise_audio(y, sr):
    stft = np.abs(librosa.stft(y))
    noise_thresh = np.mean(stft, axis=1)
    stft_denoised = np.where(stft < noise_thresh[:, None], 0, stft)
    y_denoised = librosa.istft(stft_denoised)
    return y_denoised

# %%
def resample_audio(y, sr, target_sr=16000):

    return librosa.resample(y, orig_sr=sr, target_sr=target_sr), target_sr

# %%
def segment_audio(input_file, min_silence_len=2000, silence_thresh=-30,keep_silence=200, output_dir='segments'):
    
    
    y, sr = librosa.load(input_file, sr=None)
    
    
    y_denoised = denoise_audio(y, sr)
    
   
    y_resampled, target_sr = resample_audio(y_denoised, sr)
    
    
    audio = AudioSegment(
        y_resampled.tobytes(), 
        frame_rate=target_sr, 
        sample_width=y_resampled.dtype.itemsize, 
        channels=1
    )

    
    
    # Split audio based on silence
    segments = split_on_silence(
        audio,
        min_silence_len=min_silence_len,  # Minimum silence length in ms
        silence_thresh=silence_thresh     # Silence threshold in dBFS (decibels relative to full scale)
    )
    
    # Create output directory for the file if not exists
    file_name = os.path.splitext(os.path.basename(input_file))[0]
    file_output_dir = os.path.join(output_dir, file_name)
    if not os.path.exists(file_output_dir):
        os.makedirs(file_output_dir)
    
    # Export each segment as a separate file
    for i, segment in enumerate(segments):
        segment.export(os.path.join(file_output_dir, f'segment_{i+1}.wav'), format="wav")
    
    print(f"Processed {input_file}: Total Segments = {len(segments)}")
    
    return len(segments), [seg.duration_seconds for seg in segments]

# %%
## # Function to segment all audio files in a folder with different parameters for English and CodeMixed
def segment_all_files_in_folder(folder_path, output_dir='segments'):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    # Get audio files
    audio_files = read_dataset_folder(folder_path)
    
    # Process each category with custom parameters
    for category in ['English', 'CodeMixed']:
        print(f"\nProcessing {category} Audio Files...")
        if category == 'English':
            min_silence_len = 500
            silence_thresh = -10
        elif category == 'CodeMixed':
            min_silence_len = 650
            silence_thresh = -10
            
        for file_path in audio_files[category]:
            ans = segment_audio(file_path, min_silence_len, silence_thresh, output_dir)
            print(ans)
    
    print(f"All files in {folder_path} processed and saved to {output_dir}")

# Define output directory and call the function to process files
output_dir = 'segmented_files_output'
folder_path = "C:/Programming/LanguageIdentification/Dataset"  
segment_all_files_in_folder(folder_path, output_dir=output_dir)
# Out:
# Processing English Audio Files...
# Processed C:/Programming/LanguageIdentification/Dataset\English\education_0001.wav: Total Segments = 9
# (9, [6.912, 1.023, 21.503, 30.045, 708.607, 301.343, 117.661, 36.927, 62.368])
# Processed C:/Programming/LanguageIdentification/Dataset\English\education_0002.wav: Total Segments = 117
# (117, [1.177, 3.29, 0.22, 6.61, 4.817, 2.916, 3.365, 1.047, 29.562, 1.342, 17.638, 9.346, 5.11, 3.486, 6.429, 6.561, 16.402, 6.071, 9.373, 2.545, 6.327, 1.088, 4.019, 3.206, 1.738, 8.991, 4.927, 15.823, 2.213, 0.652, 0.221, 1.911, 0.669, 1.854, 9.656, 18.912, 9.476, 1.59, 0.664, 5.982, 12.475, 4.987, 2.311, 9.511, 13.465, 13.029, 9.806, 0.536, 20.893, 5.294, 13.477, 4.512, 2.407, 3.193, 3.079, 1.706, 5.565, 4.902, 12.171, 18.979, 15.032, 9.503, 0.274, 7.686, 24.402, 14.57, 5.852, 2.635, 2.393, 3.645, 1.5, 6.759, 5.532, 0.279, 2.365, 10.406, 3.333, 6.552, 7.116, 6.583, 2.749, 5.462, 0.545, 4.182, 3.896, 2.095, 10.297, 16.128, 0.769, 5.224, 6.365, 2.547, 5.555, 0.861, 33.674, 1.985, 7.746, 55.017, 18.238, 18.164, 4.854, 4.72, 15.864, 2.58, 32.91, 8.772, 2.465, 11.325, 24.829, 21.512, 17.551, 2.561, 24.188, 13.156, 15.894, 0.252, 3.466])
# Processed C:/Programming/LanguageIdentification/Dataset\English\education_0003.wav: Total Segments = 105
# (105, [6.683, 14.524, 35.673, 3.358, 6.461, 3.26, 7.998, 5.598, 2.303, 2.715, 5.372, 9.596, 169.531, 2.746, 4.991, 5.212, 2.878, 3.327, 4.926, 90.844, 8.926, 13.34, 5.117, 2.942, 3.452, 4.766, 9.243, 5.216, 3.55, 2.429, 3.101, 5.054, 5.499, 6.014, 7.996, 1.95, 7.102, 10.044, 9.692, 18.367, 8.349, 7.517, 5.532, 9.499, 2.974, 1.407, 5.821, 3.998, 4.349, 6.909, 9.148, 8.923, 8.411, 11.58, 3.358, 12.859, 11.838, 7.133, 3.676, 3.647, 4.699, 6.141, 10.653, 9.118, 9.82, 1.722, 3.136, 0.605, 1.309, 1.725, 0.923, 2.271, 4.159, 4.605, 8.029, 9.949, 0.733, 7.195, 5.34, 3.805, 9.406, 7.357, 8.321, 10.332, 8.061, 7.004, 12.541, 7.998, 8.126, 2.878, 4.605, 1.66, 5.79, 6.141, 5.215, 7.776, 7.198, 12.316, 5.82, 8.158, 10.588, 11.133, 4.028, 7.357, 3.518])
# Processed C:/Programming/LanguageIdentification/Dataset\English\traffic_0000.wav: Total Segments = 2
# (2, [17.249, 585.344])
#
# Processing CodeMixed Audio Files...
# Processed C:/Programming/LanguageIdentification/Dataset\CodeMixed\0a8GyoWn0KRgXxTx.wav: Total Segments = 39
# (39, [6.215, 5.702, 10.917, 10.887, 13.031, 13.831, 4.413, 15.749, 3.942, 2.598, 3.784, 4.45, 5.927, 10.15, 3.079, 5.924, 1.863, 1.606, 5.739, 2.76, 12.232, 5.512, 21.863, 5.288, 18.053, 9.734, 3.717, 13.539, 2.725, 4.932, 9.767, 1.603, 20.293, 10.087, 3.428, 12.516, 27.171, 13.157, 30.693])
# Processed C:/Programming/LanguageIdentification/Dataset\CodeMixed\0jdhCdy6wPFMjRXl.wav: Total Segments = 1
# (1, [609.056])
# Processed C:/Programming/LanguageIdentification/Dataset\CodeMixed\0RDwoEVIUAhVPibN.wav: Total Segments = 1
# (1, [634.016])
# Processed C:/Programming/LanguageIdentification/Dataset\CodeMixed\0RmUBH81UE6b1jFc.wav: Total Segments = 1
# (1, [602.08])
# Processed C:/Programming/LanguageIdentification/Dataset\CodeMixed\0V7yPA2pAqrJrW7Y.wav: Total Segments = 1
# (1, [347.04])
# Processed C:/Programming/LanguageIdentification/Dataset\CodeMixed\0ypaM0qtYiXXTroM.wav: Total Segments = 1
# (1, [655.072])
# Processed C:/Programming/LanguageIdentification/Dataset\CodeMixed\0ZCBRzDx7vigtAuy.wav: Total Segments = 1
# (1, [644.992])
# All files in C:/Programming/LanguageIdentification/Dataset processed and saved to segmented_files_output

# %%
# !zip -r L1Segmentation-Final-8Oct.zip /kaggle/working/segments
# Out:
# 'zip' is not recognized as an internal or external command,
# operable program or batch file.
